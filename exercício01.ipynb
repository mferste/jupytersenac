# %%
import pandas as pd

# Criando um DataFrame fictício
data = {
    'Nome': ['Ana', 'Bruno', 'Carlos', 'Ana', 'Bruno', 'Carlos', 'Ana', 'Carlos', 'Bruno', 'Ana'],
    'Idade': [23, 25, 30, 23, 25, 30, 23, 30, 25, 23],
    'Sexo': ['F', 'M', 'M', 'F', 'M', 'M', 'F', 'M', 'M', 'F'],
    'Salário': [50000, 60000, 70000, 50000, 60000, 70000, 50000, 70000, 60000, 50000]
}

df = pd.DataFrame(data)

# %% [markdown]
# # 1) Implementar abaico o comando head do pandas

# %%
# Out:
#      Nome  Idade Sexo  Salário
# 5  Carlos     30    M    70000
# 6     Ana     23    F    50000
# 7  Carlos     30    M    70000
# 8   Bruno     25    M    60000
# 9     Ana     23    F    50000

# %% [markdown]
# # 2) Implementar abaixo o comando tail do pandas.

# %% [markdown]
# # 3) Implementar abaixo o comando describe do bandas

# %%
# Out:
#            Idade       Salário
# count  10.000000     10.000000
# mean   25.700000  59000.000000
# std     3.093003   8755.950358
# min    23.000000  50000.000000
# 25%    23.000000  50000.000000
# 50%    25.000000  60000.000000
# 75%    28.750000  67500.000000
# max    30.000000  70000.000000

# %% [markdown]
# # 4) Concluir a análise do pandas abaixo. Escrever algum detalhamento sobre o quadro acima. Qual a média de idade? Qual o valor maior de salário? E o menor? O que entendeu dos diferentes quartis?
